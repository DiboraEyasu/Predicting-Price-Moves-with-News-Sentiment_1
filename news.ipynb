# %%
import os
import sys
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# %%
# Ensure project root is on sys.path if needed (often unnecessary when running in repo root)
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)
from src.eda import NewsEDA

# %%
# Path to data file (relative to repo root)
filepath = './data/raw_analyst_ratings.csv'
# Create the EDA object with the filepath (or call load_data with filepath)
eda = NewsEDA(filepath)

# %%
# Load data and capture the returned DataFrame
df = eda.load_data()
# Out:
# ✅ Data Loaded Successfully

# %%
# Show the first few rows if loading succeeded
if df is not None:
    df.head()

# %%
# Visualize headlines and publishers (plots will display inline in the notebook)
eda.news_description()
# Out:
# Headline Length Status:
#
# count    1.407328e+06
# mean     7.312051e+01
# std      4.073531e+01
# min      3.000000e+00
# 25%      4.700000e+01
# 50%      6.400000e+01
# 75%      8.700000e+01
# max      5.120000e+02
# Name: headline_length, dtype: float64
# count    1.407328e+06
# mean     7.312051e+01
# std      4.073531e+01
# min      3.000000e+00
# 25%      4.700000e+01
# 50%      6.400000e+01
# 75%      8.700000e+01
# max      5.120000e+02
# Name: headline_length, dtype: float64

# %%
eda.time_series_analysis()

# %%
eda.clean_text()

# %%
eda.publisher_analysis()

# %%
eda.text_analysis()
